# %% [markdown]
# # Data types

# %% [markdown]
# ## Data Types (Number types)

# %%
x = 30
y = 3.142
z = 5j
print(x,y,z)
# Out:
# 30 3.142 5j

# %% [markdown]
# ## Data Types (Boolean Types)

# %% [markdown]
# x = True
# x = False
# print (x)

# %% [markdown]
# ## Data types (string)

# %% [markdown]
# name = "josh"
# print (name)

# %% [markdown]
# ## Data structure (list)

# %%
my_list = ["josh", "group"]
print (my_list)
# Out:
# ['josh', 'group']

# %% [markdown]
# ## Data Structure (tuples)

# %%
student = ("josh","james")
student
# Out:
# ('josh', 'james')

# %% [markdown]
# ## Data struture (sets)

# %% [markdown]
# student = {"josh","james"}

# %% [markdown]
# student

# %%
type(student)
# Out:
# set

# %%
my_set = {1,9,4,5,0}

# %%
my_set
# Out:
# {0, 1, 4, 5, 9}

# %% [markdown]
# ## Data Structure (Dictionary)

# %%
person = {"name":"mitchel","age":18,"color":"fair"}

# %%
person
# Out:
# {'name': 'mitchel', 'age': 18, 'color': 'fair'}

# %%
person["name"]
# Out:
# 'mitchel'

# %%
person["age"]
# Out:
# 18
